# %%
my_dict = {}
for i in range(1, 10):
    my_dict[i] = i*i
my_dict
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
import pandas as pd
df = pd.DataFrame(my_dict, index=[0, 1])
df
# Out:
#    1  2  3   4   5   6   7   8   9
# 0  1  4  9  16  25  36  49  64  81
# 1  1  4  9  16  25  36  49  64  81

# %%
x = {i: i*i for i in range(1, 10)}
x
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
my_dict2 = {}
for i in my_dict:
    my_dict2[i] = {i: i*i for i in range(1, 10)}
my_dict2
# Out:
# {1: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  2: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  3: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  4: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  5: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  6: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  7: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  8: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81},
#  9: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}}

# %%
ufo  = pd.read_csv("Desktop/uforeports.csv")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
credit = pd.read_csv("Downloads\Credit card transactions - India - Simple.csv")

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
credit.columns
# Out:
# Index(['index', 'City', 'Date', 'Card Type', 'Exp Type', 'Gender', 'Amount',
#        'year', 'month', 'day', 'Gender_num', 'City_length'],
#       dtype='object')

# %%
credit.rename(columns= {'City': 'CITY', 'Date': 'DATE'})
# Out:
#        index                   CITY       DATE  Card Type Exp Type Gender  \
# 0          0           Delhi, India 2014-10-29       Gold    Bills      F
# 1          1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F
# 2          2       Bengaluru, India 2014-08-27     Silver    Bills      F
# 3          3  Greater Mumbai, India 2014-04-12  Signature    Bills      F
# 4          4       Bengaluru, India 2015-05-05       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India 2014-06-22     Silver   Travel      F
# 26048  26048            Pune, India 2014-08-03  Signature   Travel      M
# 26049  26049       Hyderabad, India 2015-01-16     Silver   Travel      M
# 26050  26050          Kanpur, India 2014-09-14     Silver   Travel      M
# 26051  26051       Hyderabad, India 2013-10-19  Signature    Bills      M
#
#        Amount  year  month  day  Gender_num  City_length
# ...

# %%
credit.drop('index', axis=1)
# Out:
#                         City       Date  Card Type Exp Type Gender  Amount  \
# 0               Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2           Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4           Bengaluru, India 2015-05-05       Gold    Bills      F  171574
# ...                      ...        ...        ...      ...    ...     ...
# 26047         Kolkata, India 2014-06-22     Silver   Travel      F  128191
# 26048            Pune, India 2014-08-03  Signature   Travel      M  246316
# 26049       Hyderabad, India 2015-01-16     Silver   Travel      M  265019
# 26050          Kanpur, India 2014-09-14     Silver   Travel      M   88174
# 26051       Hyderabad, India 2013-10-19  Signature    Bills      M  184410
#
#        year  month  day  Gender_num  City_length
# ...

# %%
credit.shape
# Out:
# (26052, 7)

# %%
credit.isna().sum()
# Out:
# index        0
# City         0
# Date         0
# Card Type    0
# Exp Type     0
# Gender       0
# Amount       0
# dtype: int64

# %%
credit.dtypes
# Out:
# index         int64
# City         object
# Date         object
# Card Type    object
# Exp Type     object
# Gender       object
# Amount        int64
# dtype: object

# %%
credit.min()
# Out:
# index                      0
# City         Achalpur, India
# Date                1-Apr-14
# Card Type               Gold
# Exp Type               Bills
# Gender                     F
# Amount                  1005
# dtype: object

# %%
credit.max()
# Out:
# index                   26051
# City         Zunheboto, India
# Date                 9-Sep-14
# Card Type              Silver
# Exp Type               Travel
# Gender                      M
# Amount                 998077
# dtype: object

# %%
credit.describe()
# Out:
#               index         Amount
# count  26052.000000   26052.000000
# mean   13025.500000  156411.537425
# std     7520.708943  103063.254287
# min        0.000000    1005.000000
# 25%     6512.750000   77120.250000
# 50%    13025.500000  153106.500000
# 75%    19538.250000  228050.000000
# max    26051.000000  998077.000000

# %%
credit['Date']
# Out:
# 0        29-Oct-14
# 1        22-Aug-14
# 2        27-Aug-14
# 3        12-Apr-14
# 4         5-May-15
#            ...
# 26047    22-Jun-14
# 26048     3-Aug-14
# 26049    16-Jan-15
# 26050    14-Sep-14
# 26051    19-Oct-13
# Name: Date, Length: 26052, dtype: object

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
credit['Date'] = pd.to_datetime(credit.Date)

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574

# %%
credit['year'] = credit.Date.dt.year

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2015

# %%
credit['month'] = credit.Date.dt.month

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574
#
#    year  month
# 0  2014     10
# 1  2014      8
# 2  2014      8
# 3  2014      4
# 4  2015      5

# %%
credit['day'] = credit.Date.dt.day

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574
#
#    year  month  day
# 0  2014     10   29
# 1  2014      8   22
# 2  2014      8   27
# 3  2014      4   12
# 4  2015      5    5

# %%
credit['City'].value_counts()
# Out:
# Bengaluru, India          3552
# Greater Mumbai, India     3493
# Ahmedabad, India          3491
# Delhi, India              3482
# Hyderabad, India           784
#                           ...
# Rayagada, India              1
# Varanasi, India              1
# Hugli-Chinsurah, India       1
# Alirajpur, India             1
# Fazilka, India               1
# Name: City, Length: 986, dtype: int64

# %%
credit.City.nunique()
# Out:
# 986

# %%
credit['City']
# Out:
# 0                 Delhi, India
# 1        Greater Mumbai, India
# 2             Bengaluru, India
# 3        Greater Mumbai, India
# 4             Bengaluru, India
#                  ...
# 26047           Kolkata, India
# 26048              Pune, India
# 26049         Hyderabad, India
# 26050            Kanpur, India
# 26051         Hyderabad, India
# Name: City, Length: 26052, dtype: object

# %%
credit[credit['City'] == 'Bengaluru, India']
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount  \
# 2          2  Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 4          4  Bengaluru, India 2015-05-05       Gold    Bills      F  171574
# 26        26  Bengaluru, India 2014-03-23   Platinum    Bills      F  434427
# 28        28  Bengaluru, India 2015-01-18   Platinum    Bills      F  987935
# 30        30  Bengaluru, India 2014-07-31  Signature    Bills      F  225392
# ...      ...               ...        ...        ...      ...    ...     ...
# 17618  17618  Bengaluru, India 2013-11-02       Gold  Grocery      F  281540
# 17835  17835  Bengaluru, India 2014-07-15     Silver     Fuel      M  172055
# 18583  18583  Bengaluru, India 2013-11-16   Platinum     Fuel      M  191027
# 18749  18749  Bengaluru, India 2014-09-17       Gold     Food      F  113976
# 18994  18994  Bengaluru, India 2014-11-24       Gold    Bills      M   97311
#
#        year  month  day
# ...

# %%
credit['City_length'] = credit.City.apply(len)

# %%
credit.loc[0:4, ['City', 'City_length']]
# Out:
#                     City  City_length
# 0           Delhi, India           12
# 1  Greater Mumbai, India           21
# 2       Bengaluru, India           16
# 3  Greater Mumbai, India           21
# 4       Bengaluru, India           16

# %%
credit['Gender_num'] = credit.Gender.map({'F':0, 'M': 1})

# %%
credit.loc[17618:18994, ['Gender', 'Gender_num']]
# Out:
#       Gender  Gender_num
# 17618      F           0
# 17619      F           0
# 17620      F           0
# 17621      F           0
# 17622      F           0
# ...      ...         ...
# 18990      M           1
# 18991      F           0
# 18992      M           1
# 18993      M           1
# 18994      M           1
#
# [1377 rows x 2 columns]

# %%
credit.groupby('City').Amount.sum().sort_values(ascending=False).head()
# Out:
# City
# Greater Mumbai, India    576751476
# Bengaluru, India         572326739
# Ahmedabad, India         567794310
# Delhi, India             556929212
# Kolkata, India           115466943
# Name: Amount, dtype: int64

# %%
credit['Card Type']
# Out:
# 0             Gold
# 1         Platinum
# 2           Silver
# 3        Signature
# 4             Gold
#            ...
# 26047       Silver
# 26048    Signature
# 26049       Silver
# 26050       Silver
# 26051    Signature
# Name: Card Type, Length: 26052, dtype: object

# %%
credit.groupby('Card Type').City.value_counts()
# Out:
# Card Type  City
# Gold       Delhi, India             863
#            Bengaluru, India         857
#            Greater Mumbai, India    848
#            Ahmedabad, India         809
#            Chennai, India           204
#                                    ...
# Silver     Warisaliganj, India        1
#            Yadgir, India              1
#            Yavatmal, India            1
#            Yawal, India               1
#            Zira, India                1
# Name: City, Length: 3104, dtype: int64

# %%
credit.groupby('City').Gender.value_counts()
# Out:
# City              Gender
# Achalpur, India   F         5
#                   M         4
# Adilabad, India   F         5
#                   M         5
# Adityapur, India  M         4
#                            ..
# Zira, India       F         2
# Zirakpur, India   M         2
#                   F         1
# Zunheboto, India  M         2
#                   F         1
# Name: Gender, Length: 1876, dtype: int64

# %%
credit['Gender']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 26047    F
# 26048    M
# 26049    M
# 26050    M
# 26051    M
# Name: Gender, Length: 26052, dtype: object
